# %%
import numpy as np
import pandas as pd
from datetime import datetime as dt
from pathlib import Path
import matplotlib.pyplot as plt

res_df = pd.read_excel("\yourdata.xlsx")
res_df.head()
# Out:
#    Unnamed: 0    time     price  pos_conf  neg_conf  \
# 0           0  735612  5.182362       0.0  0.071429
# 1           1  735613  5.346364       0.0  0.000000
# 2           2  735614  5.338004       0.0  0.000000
# 3           3  735615  5.294610       0.0  0.000000
# 4           4  735616  5.348721       0.0  0.000000
#
#                        _fits                  Unnamed: 6  \
# 0  [{'tc': 736086.2743404938     'm': 1.8221370128202077
# 1  [{'tc': 735613.0181905315     'm': 1.3958760505431353
# 2  [{'tc': 735882.1974211377   'm': -0.16100886183895202
# 3  [{'tc': 735615.0081932249     'm': 1.4389871471210205
# 4  [{'tc': 735923.3653047463   'm': -0.16265216152200385
#
#                      Unnamed: 7                Unnamed: 8  \
# 0      'w': 0.11009134604337201   'a': -263.7876799607732
# 1    'w': -0.006059297947058891    'a': 5.359231887119872
# 2       'w': 2.6785044923942616    'a': 288.2645086328003
# 3   'w': -0.0052465136117991334    'a': 5.296778291923335
# 4        'w': 3.164644392995822   'a': 304.36432162811343
#
#                  Unnamed: 9  ...             Unnamed: 281  \
# 0   'b': 0.7770302863480624  ...   'a': 5.182055436179851
# 1    'b': 92.42228442160835  ...   'a': 5.135225239849982
# 2   'b': -722.4901324860275  ...   'a': 5.146430241113372
# 3   'b': 116.89627797661943  ...    'a': 4.72253905960158
# 4   'b': -784.9703790570716  ...    'a': 4.76351680014348
#
#                 Unnamed: 282                Unnamed: 283  \
# 0     'b': 54.68847014670824     'c': -54.67379399901089
# 1     'b': 78.93839200896174     'c': -78.92573893866103
# 2   'b': 0.05629571004541212   'c': -0.01655058464851708
# 3   'b': 0.31890081740831494    'c': 0.04213459167265192
# 4    'b': 0.2039906016281653    'c': 0.03145035641939444
#
#                    Unnamed: 284                  Unnamed: 285  \
# 0       'c1': -54.4430427914345      'c2': -5.017852315115563
# 1      'c1': -78.68944090826147      'c2': -6.102799075743695
# 2   'c1': -0.008645018972429492   'c2': -0.014113309292085376
# 3    'c1': 0.027015094404553304     'c2': 0.03233432370924404
# 4    'c1': 0.030634885476519113    'c2': -0.00711538549535466
#
#       Unnamed: 286     Unnamed: 287                Unnamed: 288  \
# 0   't1': 735598.0   't2': 735612.0   'O': 0.047938073140120774
# 1   't1': 735599.0   't2': 735613.0                    'O': nan
# 2   't1': 735600.0   't2': 735614.0     'O': 1.5392221523045515
# 3   't1': 735601.0   't2': 735615.0     'O': 1.5901741323978538
# 4   't1': 735602.0   't2': 735616.0     'O': 1.3804387464617611
#
#                Unnamed: 289              Unnamed: 290
# 0    'D': 40.04182349630632   'is_qualified': False}]
# 1    'D': 50.27325580333996   'is_qualified': False}]
# 2   'D': 0.6248354422072312   'is_qualified': False}]
# 3   'D': 0.5378858935299249   'is_qualified': False}]
# 4   'D': 0.4672415324735437   'is_qualified': False}]
#
# [5 rows x 291 columns]

# %%
ord = res_df["time"].astype("int32")
ts = [pd.Timestamp.fromordinal(d) for d in ord]

# %%
fig, ax1 = plt.subplots(figsize=(16, 8))
ax2 = ax1.twinx()

plt.ticklabel_format(style='plain', axis = 'y') 

ax1.plot(ts, res_df['pos_conf'], color='red')
ax2.plot(ts, res_df['price'], color='black')

ax1.set_xlabel('Time')  
ax2.set_xlabel('Time') 


ax1.set_ylabel('Positive bubble indicator') 
ax2.set_ylabel('ln of Price') 


plt.show()
