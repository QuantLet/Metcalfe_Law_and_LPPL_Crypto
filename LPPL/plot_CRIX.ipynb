# %%
import numpy as np
import pandas as pd
from datetime import datetime as dt
from pathlib import Path
import matplotlib.pyplot as plt

res_df = pd.read_excel("\yourdata.xlsx")
res_df.head()
# Out:
#    Unnamed: 0    time     price  pos_conf  neg_conf  \
# 0           0  736612  6.893849       0.0       0.0
# 1           1  736613  6.906765       0.0       0.0
# 2           2  736614  6.986770       0.0       0.0
# 3           3  736615  7.036113       0.0       0.0
# 4           4  736616  7.061900       0.0       0.0
#
#                        _fits                 Unnamed: 6  \
# 0  [{'tc': 736576.3621355157    'm': 0.7286457418053497
# 1   [{'tc': 860754.774249031    'm': 0.6359140944640818
# 2  [{'tc': 736581.0057878862   'm': 0.28704126384484574
# 3  [{'tc': 831708.0925563487    'm': 0.7872998390284585
# 4  [{'tc': 851070.2319505279    'm': 0.6584237438539178
#
#                  Unnamed: 7                    Unnamed: 8  \
# 0    'w': 2.168666847894303        'a': 6.974918881894338
# 1   'w': 10.267927026078844     'a': -0.17815908479265963
# 2   'w': 1.3385297611082674        'a': 6.870603136421785
# 3    'w': 7.029824479616417     'a': 0.046803160498130984
# ...

# %%
ord = res_df["time"].astype("int32")
ts = [pd.Timestamp.fromordinal(d) for d in ord]

# %%
fig, ax1 = plt.subplots(figsize=(16, 8))
ax2 = ax1.twinx()

plt.ticklabel_format(style='plain', axis = 'y') 

ax1.plot(ts, res_df['pos_conf'], color='red')
ax2.plot(ts, res_df['price'], color='black')

ax1.set_xlabel('Time', fontsize = 16)  
ax2.set_xlabel('Time', fontsize = 16) 


ax1.set_ylabel('Positive bubble indicator', fontsize = 16) 
ax2.set_ylabel('ln of Price', fontsize = 16)



plt.show()
